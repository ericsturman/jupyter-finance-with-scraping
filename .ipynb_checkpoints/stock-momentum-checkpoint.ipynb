# %%
from fetchYahooStockData import metadata_price_action, extended_stock_stats, basic_stats, current_sp500_symbols, parse_value
import numpy as np
import pandas as pd
from scipy import stats

# %%
symbol="V"
timeInterval = "1d"
timeRange = "1y"

# %%
sp500symbols = np.array(current_sp500_symbols())
sp500symbols[0]
# Out:
# 'MMM'

# %%
my_columns = ["Ticker", "Stock Price","4 Week Change", "4 Week Percentile", "12 Week Change", "12 Week Percentile", "26 Week Change", "26 Week Percentile", "52 Week Change", "52 Week Percentile", "HQM Score"]
dataframe = pd.DataFrame(columns=my_columns)
symbolCounter = 0
errorSymbols = []
basic=None
for sym in sp500symbols[:]:
    try: 
        if(sym.find(".") > -1):
            sym = sym.replace(".", "-")
        basic = basic_stats(sym)
#         complexStats = extended_stock_stats(sym)

        metadataAndPrice = metadata_price_action(sym, "1d", "1y")
        previousCloseBasic = parse_value(basic["Previous Close"])
        previousClose = metadataAndPrice["price"].iloc[-1]["close"]
        print(f'Previous Closes:  {previousCloseBasic} .... {previousClose}')

        if(len(metadataAndPrice["price"]) >= 250):
            dataLength = len(metadataAndPrice["price"])
            fourWeekChange = (metadataAndPrice["price"].iloc[-1]["close"]-metadataAndPrice["price"].iloc[dataLength-19]["close"])/metadataAndPrice["price"].iloc[dataLength-19]["close"]
            twelveWeekChange = (metadataAndPrice["price"].iloc[-1]["close"]-metadataAndPrice["price"].iloc[dataLength-59]["close"])/metadataAndPrice["price"].iloc[dataLength-59]["close"]
            twentySixWeekChange = (metadataAndPrice["price"].iloc[-1]["close"]-metadataAndPrice["price"].iloc[dataLength-129]["close"])/metadataAndPrice["price"].iloc[dataLength-129]["close"]
            fiftyTwoWeekChange = (metadataAndPrice["price"].iloc[-1]["close"]-metadataAndPrice["price"].iloc[0]["close"])/metadataAndPrice["price"].iloc[0]["close"]
            dataframe = dataframe.append(pd.Series([sym,previousClose,fourWeekChange, "N/A", twelveWeekChange, "N/A", twentySixWeekChange, "N/A", fiftyTwoWeekChange, "N/A", "N/A"], index=my_columns), ignore_index=True)
            print(symbolCounter + 1, " of ", len(sp500symbols), ":  ", sym, previousClose, fourWeekChange, twelveWeekChange, twentySixWeekChange, fiftyTwoWeekChange)
        symbolCounter = symbolCounter + 1
    except Exception as e:
        print(f'Error processing data for symbol: {sym}...{e}')
        print(f'Basic:  {basic}')
        errorSymbols.append(sym)
        print(f'Error symbols: {errorSymbols}')
        symbolCounter = symbolCounter + 1
# dataframe.sort_values("52 Week Change", ascending=False, inplace=True)
dataframe.reset_index(inplace=True)
dataframe.to_csv("lastBetterMomentumDataframe_bak.csv")
# dataframe = dataframe[:50]
dataframe
# Out:
# first attempt status code:   200
# Previous Closes:  198.1 .... 150.47000122070312
# 1  of  505 :   MMM 150.47000122070312 0.0053329425314276105 -0.025262247982401485 0.060487591289090994 0.3154781739589149
# first attempt status code:   200
# Previous Closes:  121.0 .... 100.63999938964844
# 2  of  505 :   ABT 100.63999938964844 0.018178788652222697 0.017066048430204733 0.05853532581866794 0.2021065589292648
# first attempt status code:   200
# Previous Closes:  118.8 .... 94.91000366210938
# 3  of  505 :   ABBV 94.91000366210938 0.0049252542840271946 0.004751646235488661 0.1314330383879748 0.22537138936164536
# first attempt status code:   200
# Previous Closes:  324.8 .... 299.94000244140625
# 4  of  505 :   ABMD 299.94000244140625 0.0013162229641161807 0.10218664242890353 -0.004443065818502141 0.09068484358749318
# first attempt status code:   200
# Previous Closes:  318.3 .... 224.77999877929688
# 5  of  505 :   ACN 224.77999877929688 0.040209558037709696 0.08969915276637194 0.29085731327514613 0.4132929726888175
# first attempt status code:   200
# Previous Closes:  83.5 .... 82.62999725341797
# 6  of  505 :   ATVI 82.62999725341797 -0.114194900477217 -0.11793248887420239 -0.05695269568790776 0.011981187535657472
# first attempt status code:   200
# Previous Closes:  621.7 .... 444.32000732421875
# 7  of  505 :   ADBE 444.32000732421875 0.04143069099892532 0.27192926750758134 0.3513695758322011 0.3990592245134063
# first attempt status code:   200
# Previous Closes:  102.9 .... 77.43000030517578
# 8  of  505 :   AMD 77.43000030517578 0.12406055964075381 0.34741791309479464 0.1952949889543813 0.37143228752264407
# first attempt status code:   200
# Previous Closes:  213.3 .... 150.13999938964844
# 9  of  505 :   AAP 150.13999938964844 0.01609966775028198 0.03712034182314133 0.4335159065637655 0.41241506874026573
# first attempt status code:   200
# Previous Closes:  24.1 .... 15.229999542236328
# 10  of  505 :   AES 15.229999542236328 -0.08846150911771335 -0.0810391655057898 0.03223003954591809 0.5561392958163816
# first attempt status code:   200
# Previous Closes:  55.6 .... 35.56999969482422
# 11  of  505 :   AFL 35.56999969482422 0.032476056455227505 -0.019782580614457913 0.21816164210925462 0.5462468504885322
# first attempt status code:   200
# Previous Closes:  152.6 .... 96.33000183105469
# 12  of  505 :   A 96.33000183105469 0.028527319921344208 0.1443614840341095 0.28981474571832355 0.5906778035390949
# first attempt status code:   200
# Previous Closes:  289.6 .... 286.6300048828125
# 13  of  505 :   APD 286.6300048828125 0.015032078474623482 0.0016520771175187817 0.0779686900377033 0.015350779128246865
# first attempt status code:   200
# Previous Closes:  119.2 .... 112.44000244140625
# 14  of  505 :   AKAM 112.44000244140625 0.02329546608640128 0.0822128039984335 -0.004317537877117848 0.06652432910997999
# first attempt status code:   200
# Previous Closes:  58.8 .... 34.439998626708984
# 15  of  505 :   ALK 34.439998626708984 -0.019597902928294195 -0.1453608619260524 0.1879222229666804 0.6849593813367147
# first attempt status code:   200
# Previous Closes:  202.8 .... 82.45999908447266
# 16  of  505 :   ALB 82.45999908447266 0.2223540357759587 0.26622413803127487 0.22025458003132908 1.4986659662106454
# first attempt status code:   200
# Previous Closes:  200.7 .... 177.5500030517578
# 17  of  505 :   ARE 177.5500030517578 0.0800343220442685 0.13023463022191029 0.2111404576810478 0.13399038511532868
# first attempt status code:   200
# Previous Closes:  676.9 .... 293.82000732421875
# 18  of  505 :   ALGN 293.82000732421875 0.15071031712905927 0.16288390641303663 0.36527738755550637 1.3681164333549996
# first attempt status code:   200
# Error processing data for symbol: ALLE...'Previous Close'
# Basic:  {}
# Error symbols: ['ALLE']
# first attempt status code:   200
# Error processing data for symbol: LNT...'Previous Close'
# Basic:  {}
# Error symbols: ['ALLE', 'LNT']
# first attempt status code:   200
# Previous Closes:  132.5 .... 94.38999938964844
# 21  of  505 :   ALL 94.38999938964844 -0.012528427750327276 -0.016709447655117664 0.17681658255186294 0.37779429910686213
# first attempt status code:   200
# Previous Closes:  2715.5 .... 1487.949951171875
# 22  of  505 :   GOOGL 1487.949951171875 0.06764798207687847 0.1456676464069931 0.481373830965355 0.8109009830436336
# first attempt status code:   200
# Previous Closes:  2730.8 .... 1482.9599609375
# 23  of  505 :   GOOG 1482.9599609375 0.041997057617272016 0.12745706528852724 0.47718736948113566 0.823663479198262
# first attempt status code:   200
# Previous Closes:  48.6 .... 41.150001525878906
# 24  of  505 :   MO 41.150001525878906 0.02935510607098427 -0.0382382345993724 0.14873269407204068 0.16743618795045176
# first attempt status code:   200
# Previous Closes:  3599.9 .... 3164.679931640625
# 25  of  505 :   AMZN 3164.679931640625 -0.09471559557224042 0.0109308147971787 0.0293913862826049 0.05147760903755741
# first attempt status code:   200
# Previous Closes:  11.6 .... 10.300000190734863
# 26  of  505 :   AMCR 10.300000190734863 0.010489584233828947 -0.07148589584604739 0.04520795488517063 0.12233011704361338
# first attempt status code:   200
# Error processing data for symbol: AEE...'Previous Close'
# Basic:  {}
# Error symbols: ['ALLE', 'LNT', 'AEE']
# first attempt status code:   200
# Previous Closes:  21.1 .... 11.119999885559082
# 28  of  505 :   AAL 11.119999885559082 -0.029985771596955542 -0.07363640178333629 0.2306763175132043 0.8327337563404977
# first attempt status code:   200
# Previous Closes:  89.1 .... 86.87999725341797
# 29  of  505 :   AEP 86.87999725341797 0.03378701261132503 0.01066636402265 0.09547488901147179 0.014272623530904626
# first attempt status code:   200
# Previous Closes:  171.9 .... 93.31999969482422
# 30  of  505 :   AXP 93.31999969482422 0.005720696123317223 0.07265066902852534 0.4946972061796961 0.8273681883515366
# first attempt status code:   200
# Previous Closes:  47.7 .... 32.13999938964844
# 31  of  505 :   AIG 32.13999938964844 0.015876375328885663 -0.07501465629233921 0.25930852116152664 0.47324204646287116
# first attempt status code:   200
# Previous Closes:  283.0 .... 261.3900146484375
# 32  of  505 :   AMT 261.3900146484375 0.02564094050317644 0.14267235652382734 0.2346109788140911 0.08190815235741536
# first attempt status code:   200
# Previous Closes:  170.7 .... 147.27000427246094
# 33  of  505 :   AWK 147.27000427246094 0.06398546043976767 0.11350393305589779 0.08543899492950989 0.15508926241106682
# first attempt status code:   200
# Previous Closes:  259.2 .... 153.6300048828125
# 34  of  505 :   AMP 153.6300048828125 0.041951515088663814 -0.03045359128087557 0.27846713479169666 0.6764954069685675
# first attempt status code:   200
# Previous Closes:  118.2 .... 100.19000244140625
# 35  of  505 :   ABC 100.19000244140625 0.05848206642768898 0.010838967002963508 0.14348560797935864 0.21938312398378812
# first attempt status code:   200
# Error processing data for symbol: AME...'Previous Close'
# Basic:  {}
# Error symbols: ['ALLE', 'LNT', 'AEE', 'AME']
# first attempt status code:   200
# Previous Closes:  244.8 .... 244.6699981689453
# 37  of  505 :   AMGN 244.6699981689453 -0.008659965783738144 -0.049840734405060004 -0.037919239883044714 -0.012792761295772859
# first attempt status code:   200
# Previous Closes:  71.9 .... 52.880001068115234
# 38  of  505 :   APH 52.880001068115234 0.04588083129692006 0.06430769658152496 0.15457510615503242 0.37083956882668123
# first attempt status code:   200
# Previous Closes:  166.5 .... 114.8499984741211
# 39  of  505 :   ADI 114.8499984741211 -0.00534701233430816 0.06460640987538462 0.13520479399961657 0.45772747403797054
# first attempt status code:   200
# Previous Closes:  365.3 .... 310.6000061035156
# 40  of  505 :   ANSS 310.6000061035156 0.036047621973341826 0.1085504123058978 0.05621322920585976 0.18628455960905274

# %%
dataframe.to_csv("momentum_almost.csv")

# %%
time_periods = [
                '52 Week',
                '26 Week',
                '12 Week',
                '4 Week'
                ]

for row in dataframe.index:
    for time_period in time_periods:
        dataframe.loc[row, f'{time_period} Percentile'] = stats.percentileofscore(dataframe[f'{time_period} Change'], dataframe.loc[row, f'{time_period} Change'])/100

from statistics import mean

for row in dataframe.index:
    momentum_percentiles = []
    for time_period in time_periods:
        momentum_percentiles.append(dataframe.loc[row, f'{time_period} Percentile'])
    dataframe.loc[row, 'HQM Score'] = mean(momentum_percentiles)
sorted_dataframe = dataframe.sort_values(by = 'HQM Score', ascending = False)
sorted_dataframe.to_csv("momentum_last.csv")
sorted_dataframe
# Out:
#      index Ticker  Stock Price  4 Week Change 4 Week Percentile  \
# 283    283   MRNA        323.4       0.564681               1.0
# 184    184   GNRC        444.5       0.098854           0.96468
# 176    176   FTNT        270.7       0.116054          0.984547
# 245    245     LB         76.3       0.096942          0.958057
# 197    197    HCA        246.7       0.200754          0.995585
# ..     ...    ...          ...            ...               ...
# 218    218   INTC         55.9      -0.077940          0.090508
# 263    263    MTB        128.9      -0.120264          0.028698
# 332    332    PSX         71.1      -0.155116          0.006623
# 216    216   INCY         78.6      -0.073706          0.103753
# 250    250    LVS         47.2      -0.109013          0.041943
#
#      12 Week Change 12 Week Percentile  26 Week Change 26 Week Percentile  \
# 283        0.950732                1.0        1.787518                1.0
# 184        0.387992           0.997792        0.672830            0.99117
# 176        0.349998           0.995585        0.834520           0.997792
# 245        0.181335           0.933775        0.708736           0.995585
# 197        0.235751           0.966887        0.479369           0.986755
# ..              ...                ...             ...                ...
# 218       -0.078742            0.15011       -0.096642           0.046358
# 263       -0.179847            0.01766       -0.100188            0.04415
# 332       -0.108021           0.090508       -0.042711             0.0883
# 216       -0.071211           0.169978       -0.177130           0.011038
# 250       -0.252857           0.002208       -0.159103            0.01766
#
#      52 Week Change 52 Week Percentile HQM Score
# 283        3.764786                1.0       1.0
# 184        2.324510           0.995585  0.987307
# 176        1.072384           0.942605  0.980132
# 245        3.056800           0.997792  0.971302
# 197        0.979603           0.916115  0.966336
# ..              ...                ...       ...
# 218        0.047638           0.103753  0.097682
# 263        0.230191           0.289183  0.094923
# 332        0.109284           0.152318  0.084437
# 216       -0.202374           0.004415  0.072296
# 250        0.031785             0.0883  0.037528
#
# [453 rows x 12 columns]

# %%
metadataAndPrice = metadata_price_action(symbol, timeInterval, timeRange)
metadata = metadataAndPrice["metadata"]
metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'V',
#  'exchangeName': 'NYQ',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 1205933400,
#  'regularMarketTime': 1614373202,
#  'gmtoffset': -18000,
#  'timezone': 'EST',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 212.39,
#  'chartPreviousClose': 187.21,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EST',
#    'start': 1614330000,
#    'end': 1614349800,
#    'gmtoffset': -18000},
#   'regular': {'timezone': 'EST',
#    'start': 1614349800,
#    'end': 1614373200,
#    'gmtoffset': -18000},
#   'post': {'timezone': 'EST',
#    'start': 1614373200,
#    'end': 1614387600,
#    'gmtoffset': -18000}},
#  'dataGranularity': '1d',
#  'range': '1y',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
price = metadataAndPrice["price"]
price
# Out:
#       timestamp        high    volume       close        open         low
# 0    1582813800  186.339996  17536600  180.009995  182.119995  180.000000
# 1    1582900200  182.330002  22674700  181.759995  173.789993  172.979996
# 2    1583159400  192.440002  17434500  192.330002  186.320007  183.100006
# 3    1583245800  194.039993  15226400  185.729996  193.199997  184.500000
# 4    1583332200  194.490005  10789100  194.289993  190.360001  186.169998
# ..          ...         ...       ...         ...         ...         ...
# 248  1614004200  210.649994   8332700  208.320007  203.550003  203.110001
# 249  1614090600  213.910004  10568500  212.110001  207.399994  206.550003
# 250  1614177000  220.529999  12005100  219.429993  212.360001  211.289993
# 251  1614263400  220.449997  11400200  213.750000  219.289993  212.580002
# 252  1614349800  215.210007  11726800  212.389999  214.050003  210.740005
#
# [253 rows x 6 columns]

# %%
basicStats = basic_stats(symbol)
basicStats
# Out:
# STATS <Response [200]>
# {'Previous Close': '213.75',
#  'Open': '214.05',
#  'Bid': '212.01 x 900',
#  'Ask': '212.74 x 3100',
#  "Day's Range": '210.74 - 215.21',
#  '52 Week Range': '133.93 - 220.53',
#  'Volume': '11,730,004',
#  'Avg. Volume': '9,401,263',
#  'Market Cap': '468.288B',
#  'Beta (5Y Monthly)': '0.98',
#  'PE Ratio (TTM)': '43.85',
#  'EPS (TTM)': '4.84',
#  'Earnings Date': 'Apr 28, 2021 - May 03, 2021',
#  'Forward Dividend & Yield': '1.28 (0.60%)',
#  'Ex-Dividend Date': 'Feb 11, 2021'}

# %%
extStats = extended_stock_stats(symbol)
extStats
# Out:
# {'Market Cap (intraday) 5': ['483.81B',
#   '482.33B',
#   '438.37B',
#   '424.23B',
#   '354.81B',
#   '416.79B'],
#  'Enterprise Value 3': ['490.51B',
#   '491.45B',
#   '447.91B',
#   '435.44B',
#   '364.29B',
#   '426.91B'],
#  'Trailing P/E ': ['45.24', '44.73', '38.02', '34.74', '29.40', '35.32'],
#  'Forward P/E 1': ['40.65', '39.84', '34.25', '32.15', '28.74', '30.12'],
#  'PEG Ratio (5 yr expected) 1': ['1.88',
#   '3.69',
#   '2.35',
#   '2.37',
#   '2.01',
#   '2.06'],
#  'Price/Sales (ttm)': ['22.61', '22.26', '19.52', '18.17', '15.47', '18.58'],
#  'Price/Book (mrq)': ['13.80', '15.50', '14.06', '14.12', '11.90', '14.26'],
#  'Enterprise Value/Revenue 3': ['22.84',
#   '86.42',
#   '87.81',
#   '90.02',
#   '62.23',
#   '70.52'],
#  'Enterprise Value/EBITDA 6': ['32.95',
#   '120.42',
#   '131.89',
#   '133.12',
#   '88.01',
#   '101.69'],
#  'Beta (5Y Monthly) ': '0.98',
#  '52-Week Change 3': '11.14%',
#  'S&P500 52-Week Change 3': '16.75%',
#  '52 Week High 3': '220.53',
#  '52 Week Low 3': '133.93',
#  '50-Day Moving Average 3': '206.01',
#  '200-Day Moving Average 3': '204.93',
#  'Avg Vol (3 month) 3': '9.4M',
#  'Avg Vol (10 day) 3': '10.43M',
#  'Shares Outstanding 5': '1.7B',
#  'Float ': '1.69B',
#  '% Held by Insiders 1': '0.11%',
#  '% Held by Institutions 1': '96.02%',
#  'Shares Short (Feb 11, 2021) 4': '24.92M',
#  'Short Ratio (Feb 11, 2021) 4': '2.28',
#  'Short % of Float (Feb 11, 2021) 4': '1.47%',
#  'Short % of Shares Outstanding (Feb 11, 2021) 4': '1.17%',
#  'Shares Short (prior month Jan 14, 2021) 4': '31.6M',
#  'Forward Annual Dividend Rate 4': '1.28',
#  'Forward Annual Dividend Yield 4': '0.60%',
#  'Trailing Annual Dividend Rate 3': '1.24',
#  'Trailing Annual Dividend Yield 3': '0.58%',
#  '5 Year Average Dividend Yield 4': '0.62',
#  'Payout Ratio 4': '25.15%',
#  'Dividend Date 3': 'Feb 28, 2021',
#  'Ex-Dividend Date 4': 'Feb 10, 2021',
#  'Last Split Factor 2': '4:1',
#  'Last Split Date 3': 'Mar 18, 2015',
#  'Fiscal Year Ends ': 'Sep 29, 2020',
#  'Most Recent Quarter (mrq)': 'Dec 30, 2020',
#  'Profit Margin ': '49.91%',
#  'Operating Margin (ttm)': '64.97%',
#  'Return on Assets (ttm)': '11.24%',
#  'Return on Equity (ttm)': '29.39%',
#  'Revenue (ttm)': '21.48B',
#  'Revenue Per Share (ttm)': '10.07',
#  'Quarterly Revenue Growth (yoy)': '-6.10%',
#  'Gross Profit (ttm)': '21.12B',
#  'EBITDA ': '14.74B',
#  'Net Income Avi to Common (ttm)': '10.36B',
#  'Diluted EPS (ttm)': '4.84',
#  'Quarterly Earnings Growth (yoy)': '-4.50%',
#  'Total Cash (mrq)': '18.04B',
#  'Total Cash Per Share (mrq)': '8.44',
#  'Total Debt (mrq)': '21.06B',
#  'Total Debt/Equity (mrq)': '55.88',
#  'Current Ratio (mrq)': '2.12',
#  'Book Value Per Share (mrq)': '15.90',
#  'Operating Cash Flow (ttm)': '10.08B'}
